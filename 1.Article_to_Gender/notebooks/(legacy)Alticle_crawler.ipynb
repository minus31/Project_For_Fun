# %% [markdown]
# # 다음 뉴스의 성별 많이 본 뉴스 크롤링
#
#
# - 다음 뉴스에서는 연령대 별 많이 본 뉴스를 보여주는 서비스를 제공한다. [Link](http://media.daum.net/ranking/age/)
#   여기서, 연령대 마다 성별을 나누어 제공해준다.
#
# - 크롤링 함수를 재사용 가능하게 만들어 볼까 했지만, 이 문제에서만 사용할 수 있도록 만들었다.
#
# - 크롤링은
#     오늘을 기준 **2018년 7월 28일** 으로 하여, 일 년 전까지 **2017년 7월 28일** 의 데이터를 수집 하겠다.

# %%
import requests 
from bs4 import BeautifulSoup 
import re 
import datetime


def clawler(date):
    """
    only for this case, withdrawing title and body 
    
    :argument:
    date : string format ; ex) 20180726
    
    :return:
    "male_array", "female_array" 
    , which have four types of information as below 
    "date, title, label, body"
        label(0: man, 1: woman)

    """
    res = requests.get("http://media.daum.net/ranking/age/?regDate={}".format(date))
    soup = BeautifulSoup(res.content, "html.parser")
    
    male_title_list = []
    female_title_list = []
    
    male_body_list = []
    female_body_list = []
    
    
    age_range = list(range(10, 51, 10))
    
    for age in age_range:
        ## title 
        age_block = soup.select_one("div.item_age.item_{}s".format(age))
        
        male_a = age_block.select("div.rank_male a")
        female_a = age_block.select("div.rank_female a")
        
        male_title = [t.get_text() for t in male_a]
        female_title = [t.get_text() for t in female_a]
        
        male_title_list += male_title
        female_title_list += female_title
        
        ## Body 
        male_links = [li["href"] for li in male_a]
        female_links = [li["href"] for li in female_a]
        
        male_bodies = [alticle_parser_by_link(link) for link in male_links]
        female_bodies = [alticle_parser_by_link(link) for link in female_links]
        
        male_body_list += male_bodies
        female_body_list += female_bodies 
        
    male_date = [date] * len(male_title_list)
    female_date = [date] * len(female_title_list)
        
    male_array = np.stack([np.array(male_date), np.array(male_title_list), 
                           np.zeros(len(male_title_list)), np.array(male_body_list)], axis=-1)
    
    female_array = np.stack([np.array(female_date), np.array(female_title_list), 
                             np.ones(len(female_title_list)), np.array(female_body_list)], axis=-1)
    
    return male_array, female_array

def alticle_parser_by_link(link):
    """
    take alticles` body from link
    
    """
    
    res = requests.get(link)
    soup = BeautifulSoup(res.content, "html.parser")
    
    body = soup.select_one("section").get_text()
    
    # body contents processing 
    body = body.strip().replace("\n", "")
    body = re.sub(r"\w+@.+", "", body)
    body = re.sub(r"[가-하]+ 기자", "", body)
    body = body.strip()
    return body

# %% [markdown]
# ## Executing crawler

# %%
article = pd.DataFrame(columns=["date", "Title", "sex", "Body"])
today = datetime.datetime.now() - datetime.timedelta(days=i)

# %%
# 1년 치 데이터 
for i in range(365): 
    
    date = today - datetime.timedelta(days=i)
    date = date.strftime('%Y%m%d')
    
    print("date : {} started".format(date))
    male_array, female_array = clawler(date)
    article = article.append(pd.DataFrame(np.concatenate([male_array, female_array]), columns=["date", "Title", "sex", "Body"]))
    print("date : {} done \n".format(date))
# Out:
# date : 20180728 started
# date : 20180728 done
#
# date : 20180727 started
# date : 20180727 done
#
# date : 20180726 started
# date : 20180726 done
#
# date : 20180725 started
# date : 20180725 done
#
# date : 20180724 started
# date : 20180724 done
#
# date : 20180723 started
# date : 20180723 done
#
# date : 20180722 started
# date : 20180722 done
#
# date : 20180721 started
# date : 20180721 done
#
# date : 20180720 started
# date : 20180720 done
#
# date : 20180719 started
# date : 20180719 done
#
# date : 20180718 started
# date : 20180718 done
#
# date : 20180717 started
# date : 20180717 done
#
# date : 20180716 started
# date : 20180716 done
#
# date : 20180715 started
# date : 20180715 done
#
# date : 20180714 started
# date : 20180714 done
#
# date : 20180713 started
# date : 20180713 done
#
# date : 20180712 started
# date : 20180712 done
#
# date : 20180711 started
# date : 20180711 done
#
# date : 20180710 started
# date : 20180710 done
#
# date : 20180709 started
# date : 20180709 done
#
# date : 20180708 started
# date : 20180708 done
#
# date : 20180707 started
# date : 20180707 done
#
# date : 20180706 started
# date : 20180706 done
#
# date : 20180705 started
# date : 20180705 done
#
# date : 20180704 started
# date : 20180704 done
#
# date : 20180703 started
# date : 20180703 done
#
# date : 20180702 started
# date : 20180702 done
#
# date : 20180701 started
# date : 20180701 done
#
# date : 20180630 started
# date : 20180630 done
#
# date : 20180629 started
# date : 20180629 done
#
# date : 20180628 started
# date : 20180628 done
#
# date : 20180627 started
# date : 20180627 done
#
# date : 20180626 started
# date : 20180626 done
#
# date : 20180625 started
# date : 20180625 done
#
# date : 20180624 started
# date : 20180624 done
#
# date : 20180623 started
# date : 20180623 done
#
# date : 20180622 started
# date : 20180622 done
#
# date : 20180621 started
# date : 20180621 done
#
# date : 20180620 started
# date : 20180620 done
#
# date : 20180619 started
# date : 20180619 done
#
# date : 20180618 started
# date : 20180618 done
#
# date : 20180617 started
# date : 20180617 done
#
# date : 20180616 started
# date : 20180616 done
#
# date : 20180615 started
# date : 20180615 done
#
# date : 20180614 started
# date : 20180614 done
#
# date : 20180613 started
# date : 20180613 done
#
# date : 20180612 started
# date : 20180612 done
#
# date : 20180611 started
# date : 20180611 done
#
# date : 20180610 started
# date : 20180610 done
#
# date : 20180609 started
# date : 20180609 done
#
# date : 20180608 started
# date : 20180608 done
#
# date : 20180607 started
# date : 20180607 done
#
# date : 20180606 started
# date : 20180606 done
#
# date : 20180605 started
# date : 20180605 done
#
# date : 20180604 started
# date : 20180604 done
#
# date : 20180603 started
# date : 20180603 done
#
# date : 20180602 started
# date : 20180602 done
#
# date : 20180601 started
# date : 20180601 done
#
# date : 20180531 started
# date : 20180531 done
#
# date : 20180530 started
# date : 20180530 done
#
# date : 20180529 started
# date : 20180529 done
#
# date : 20180528 started
# date : 20180528 done
#
# date : 20180527 started
# date : 20180527 done
#
# date : 20180526 started
# date : 20180526 done
#
# date : 20180525 started
# date : 20180525 done
#
# date : 20180524 started
# date : 20180524 done
#
# date : 20180523 started
# date : 20180523 done
#
# date : 20180522 started
# date : 20180522 done
#
# date : 20180521 started
# date : 20180521 done
#
# date : 20180520 started
# date : 20180520 done
#
# date : 20180519 started
# date : 20180519 done
#
# date : 20180518 started
# date : 20180518 done
#
# date : 20180517 started
# date : 20180517 done
#
# date : 20180516 started
# date : 20180516 done
#
# date : 20180515 started
# date : 20180515 done
#
# date : 20180514 started
# date : 20180514 done
#
# date : 20180513 started
# date : 20180513 done
#
# date : 20180512 started
# date : 20180512 done
#
# date : 20180511 started
# date : 20180511 done
#
# date : 20180510 started
# date : 20180510 done
#
# date : 20180509 started
# date : 20180509 done
#
# date : 20180508 started
# date : 20180508 done
#
# date : 20180507 started
# date : 20180507 done
#
# date : 20180506 started
# date : 20180506 done
#
# date : 20180505 started
# date : 20180505 done
#
# date : 20180504 started
# date : 20180504 done
#
# date : 20180503 started
# date : 20180503 done
#
# date : 20180502 started
# date : 20180502 done
#
# date : 20180501 started
# date : 20180501 done
#
# date : 20180430 started
# date : 20180430 done
#
# date : 20180429 started
# date : 20180429 done
#
# date : 20180428 started
# date : 20180428 done
#
# date : 20180427 started
# date : 20180427 done
#
# date : 20180426 started
# date : 20180426 done
#
# date : 20180425 started
# date : 20180425 done
#
# date : 20180424 started
# date : 20180424 done
#
# date : 20180423 started
# date : 20180423 done
#
# date : 20180422 started
# date : 20180422 done
#
# date : 20180421 started
# date : 20180421 done
#
# date : 20180420 started
# date : 20180420 done
#
# date : 20180419 started
# date : 20180419 done
#
# date : 20180418 started
# date : 20180418 done
#
# date : 20180417 started
# date : 20180417 done
#
# date : 20180416 started
# date : 20180416 done
#
# date : 20180415 started
# date : 20180415 done
#
# date : 20180414 started
# date : 20180414 done
#
# date : 20180413 started
# date : 20180413 done
#
# date : 20180412 started
# date : 20180412 done
#
# date : 20180411 started
# date : 20180411 done
#
# date : 20180410 started
# date : 20180410 done
#
# date : 20180409 started
# date : 20180409 done
#
# date : 20180408 started
# date : 20180408 done
#
# date : 20180407 started
# date : 20180407 done
#
# date : 20180406 started
# date : 20180406 done
#
# date : 20180405 started
# date : 20180405 done
#
# date : 20180404 started
# date : 20180404 done
#
# date : 20180403 started
# date : 20180403 done
#
# date : 20180402 started
# date : 20180402 done
#
# date : 20180401 started
# date : 20180401 done
#
# date : 20180331 started
# date : 20180331 done
#
# date : 20180330 started
# date : 20180330 done
#
# date : 20180329 started
# date : 20180329 done
#
# date : 20180328 started
# date : 20180328 done
#
# date : 20180327 started
# date : 20180327 done
#
# date : 20180326 started
# date : 20180326 done
#
# date : 20180325 started
# date : 20180325 done
#
# date : 20180324 started
# date : 20180324 done
#
# date : 20180323 started
# date : 20180323 done
#
# date : 20180322 started
# date : 20180322 done
#
# date : 20180321 started
# date : 20180321 done
#
# date : 20180320 started
# date : 20180320 done
#
# date : 20180319 started
# date : 20180319 done
#
# date : 20180318 started
# date : 20180318 done
#
# date : 20180317 started
# date : 20180317 done
#
# date : 20180316 started
# date : 20180316 done
#
# date : 20180315 started
# date : 20180315 done
#
# date : 20180314 started
# date : 20180314 done
#
# date : 20180313 started
# date : 20180313 done
#
# date : 20180312 started
# date : 20180312 done
#
# date : 20180311 started
# date : 20180311 done
#
# date : 20180310 started
# date : 20180310 done
#
# date : 20180309 started
# date : 20180309 done
#
# date : 20180308 started
# date : 20180308 done
#
# date : 20180307 started
# date : 20180307 done
#
# date : 20180306 started
# date : 20180306 done
#
# date : 20180305 started
# date : 20180305 done
#
# date : 20180304 started
# date : 20180304 done
#
# date : 20180303 started
# date : 20180303 done
#
# date : 20180302 started
# date : 20180302 done
#
# date : 20180301 started
# date : 20180301 done
#
# date : 20180228 started
# date : 20180228 done
#
# date : 20180227 started
# date : 20180227 done
#
# date : 20180226 started
# date : 20180226 done
#
# date : 20180225 started
# date : 20180225 done
#
# date : 20180224 started
# date : 20180224 done
#
# date : 20180223 started
# date : 20180223 done
#
# date : 20180222 started
# date : 20180222 done
#
# date : 20180221 started
# date : 20180221 done
#
# date : 20180220 started
# date : 20180220 done
#
# date : 20180219 started
# date : 20180219 done
#
# date : 20180218 started
# date : 20180218 done
#
# date : 20180217 started
# date : 20180217 done
#
# date : 20180216 started
# date : 20180216 done
#
# date : 20180215 started
# date : 20180215 done
#
# date : 20180214 started
# date : 20180214 done
#
# date : 20180213 started
# date : 20180213 done
#
# date : 20180212 started
# date : 20180212 done
#
# date : 20180211 started
# date : 20180211 done
#
# date : 20180210 started
# date : 20180210 done
#
# date : 20180209 started
# date : 20180209 done
#
# date : 20180208 started
# date : 20180208 done
#
# date : 20180207 started
# date : 20180207 done
#
# date : 20180206 started
# date : 20180206 done
#
# date : 20180205 started
# date : 20180205 done
#
# date : 20180204 started
# date : 20180204 done
#
# date : 20180203 started
# date : 20180203 done
#
# date : 20180202 started
# date : 20180202 done
#
# date : 20180201 started
# date : 20180201 done
#
# date : 20180131 started
# date : 20180131 done
#
# date : 20180130 started
# date : 20180130 done
#
# date : 20180129 started
# date : 20180129 done
#
# date : 20180128 started
# date : 20180128 done
#
# date : 20180127 started
# date : 20180127 done
#
# date : 20180126 started
# date : 20180126 done
#
# date : 20180125 started
# date : 20180125 done
#
# date : 20180124 started
# date : 20180124 done
#
# date : 20180123 started
# date : 20180123 done
#
# date : 20180122 started
# date : 20180122 done
#
# date : 20180121 started
# date : 20180121 done
#
# date : 20180120 started
# date : 20180120 done
#
# date : 20180119 started
# date : 20180119 done
#
# date : 20180118 started
# date : 20180118 done
#
# date : 20180117 started
# date : 20180117 done
#
# date : 20180116 started
# date : 20180116 done
#
# date : 20180115 started
# date : 20180115 done
#
# date : 20180114 started
# date : 20180114 done
#
# date : 20180113 started
# date : 20180113 done
#
# date : 20180112 started
# date : 20180112 done
#
# date : 20180111 started
# date : 20180111 done
#
# date : 20180110 started
# date : 20180110 done
#
# date : 20180109 started
# date : 20180109 done
#
# date : 20180108 started
# date : 20180108 done
#
# date : 20180107 started
# date : 20180107 done
#
# date : 20180106 started
# date : 20180106 done
#
# date : 20180105 started
# date : 20180105 done
#
# date : 20180104 started
# date : 20180104 done
#
# date : 20180103 started
# date : 20180103 done
#
# date : 20180102 started
# date : 20180102 done
#
# date : 20180101 started
# date : 20180101 done
#
# date : 20171231 started
# date : 20171231 done
#
# date : 20171230 started
# date : 20171230 done
#
# date : 20171229 started
# date : 20171229 done
#
# date : 20171228 started
# date : 20171228 done
#
# date : 20171227 started
# date : 20171227 done
#
# date : 20171226 started
# date : 20171226 done
#
# date : 20171225 started
# date : 20171225 done
#
# date : 20171224 started
# date : 20171224 done
#
# date : 20171223 started
# date : 20171223 done
#
# date : 20171222 started
# date : 20171222 done
#
# date : 20171221 started
# date : 20171221 done
#
# date : 20171220 started
# date : 20171220 done
#
# date : 20171219 started
# date : 20171219 done
#
# date : 20171218 started
# Out:
#            date                                          Title  sex  \
# 18167  20170729                 "하부지 하부지" 황혼 육아 10년, 내 삶이 바뀌었다  1.0
# 18168  20170729             '놀러 안가고 외식도 안해'..숙박·음식점생산 최장기 마이너스  1.0
# 18169  20170729  [토요정담] 유쾌한 장하성 vs 섬세한 변양균 .. 경제팀 장악한 '변·장 라인'  1.0
# 18170  20170729               [일상톡톡 플러스] "형제, 자매도 결혼하면 남남이라고?"  1.0
# 18171  20170729              [단독] 최순실 은닉 재산의 핵심 '임선이 일가' 최초 공개  1.0
#
#                                                     Body
# 18167  [오마이뉴스 글:문운주, 편집:김지현]【오마이뉴스는 개인의 일상을 소재로 한 생활글...
# 18168  음식점[연합뉴스DB]          (세종=연합뉴스) 김수현 기자 = 가계의 주머...
# 18169  문재인 정부의 경제 라인에 ‘변양균-장하성’ 양강구도가 형성되는 기류가 나타나고 있...
# 18170  A(40)씨는 "형제, 자매는 사이가 좋지 않으면 되레 남보다도 못하다"며 "특히 ...
# 18171  국정농단 사건의 주범인 최순실씨 일가의 은닉 재산을 국가로 환수하기 위한 ‘박근혜 ...

# %%
import pickle 

with open("article.bin", "wb") as f :
    
    pickle.dump(article, f)

# %%
with open("article.bin", "rb") as f :
    ar = pickle.load(f)
    
ar.tail()
# Out:
#            date                                          Title  sex  \
# 18167  20170729                 "하부지 하부지" 황혼 육아 10년, 내 삶이 바뀌었다  1.0
# 18168  20170729             '놀러 안가고 외식도 안해'..숙박·음식점생산 최장기 마이너스  1.0
# 18169  20170729  [토요정담] 유쾌한 장하성 vs 섬세한 변양균 .. 경제팀 장악한 '변·장 라인'  1.0
# 18170  20170729               [일상톡톡 플러스] "형제, 자매도 결혼하면 남남이라고?"  1.0
# 18171  20170729              [단독] 최순실 은닉 재산의 핵심 '임선이 일가' 최초 공개  1.0
#
#                                                     Body
# 18167  [오마이뉴스 글:문운주, 편집:김지현]【오마이뉴스는 개인의 일상을 소재로 한 생활글...
# 18168  음식점[연합뉴스DB]          (세종=연합뉴스) 김수현 기자 = 가계의 주머...
# 18169  문재인 정부의 경제 라인에 ‘변양균-장하성’ 양강구도가 형성되는 기류가 나타나고 있...
# 18170  A(40)씨는 "형제, 자매는 사이가 좋지 않으면 되레 남보다도 못하다"며 "특히 ...
# 18171  국정농단 사건의 주범인 최순실씨 일가의 은닉 재산을 국가로 환수하기 위한 ‘박근혜 ...

# %%
ar.loc[18167].Body
# Out:
# '[오마이뉴스 글:문운주, 편집:김지현]【오마이뉴스는 개인의 일상을 소재로 한 생활글도 뉴스로 채택하고 있습니다. 개인의 경험을 통해 뉴스를 좀더 생생하고 구체적으로 파악할 수 있습니다. 당신의 이야기가 오마이뉴스에 오면 뉴스가 됩니다. 당신의 이야기를 들려주세요.】"애들 크면 당신 곁에는 누가 있을까?"아침, 집을 나서는데 아내의 걱정이 들려온다.\xa010년 전 다니던 직장을 퇴직하고 손녀를 봐주고 있다. \'하부지의 육아일기\'를 쓰면서 성장 과정을 영상과 글로 남기고 있다. 손녀 콩이와 콩콩이 이야기다. 백일 때부터 기록한 성장 일지를 다시 보는 게 크나큰 즐거움이다. \'은�
관심이 별로 없었다.\xa0하지만 아이를 보다 보니\xa0귀엽고 예쁘게 보이는 순간을 마주하게 됐고, 나도 모르게 \'찰칵\' 하다 보니 사진에 입문하게 됐다. 그렇게 시작한 사진을\xa0시기와 상황에 맞게 고르고 스토리를 만들었다. 그렇게 콩이와 콩콩이는 나만의 전속모델이,\xa0이야기의 주연배우가 됐다.\xa0"할아버지 몇 살이야?""..."콩이와 대화 내용이다. 하부지의 육아일기를 써서 <오마이뉴스>에 기사로 올렸다. 어느 포털사이트의 메인에 배치되고 댓글이 엄청나게 달렸다.\xa0그 댓글이라는 게 대부분 비난성 댓글이었다.\xa0생후 36개월도 되지 않을 때였다. 그런데 버릇이 없다느니, 할아버지가 아이를\xa0버린다느니 말이 많았다.\xa0근무 중이던 딸이 전화로\xa0"제발 글 올리지 마세요"라고 당부한 적도 있었다. 할아버지와 말동무해준 것이 고마워서 그 이야기를 적었을 뿐이었다. "할아버지 우리 부산 다녀왔다~~!"손녀들은 매일 일어난 일을 종알종알 들려준다. 자랑하려는 속셈이겠다.\xa0지난 주말에 부산에\xa0다녀온 모양이다.\xa0해수욕도 하고 엄마가 선물도 사줬다고 재잘재잘 설명한다. 엄마 아빠의 일과를 날마다 알려주기도 한다.\xa0어디 그뿐이랴. 학교에서 \'베프\'(베스트 프렌드)와 도서관에 갔고,\xa0선생님이 누구를 나쁘다고 했다는 이야기도 들을 수 있다. 아이들이라면 손사래를 치는 내 친구들도 영상이나 육아일기를 보고 무척 부러워한다. 육아를 통해 익힌 동영상 편집, 사진 촬영 기술은 친구들과의 여행에서도 유감없이 써먹을 수 있게 됐다. 나중에는 여행기로 결과물을 내놨다. 사람들이 말하는 \'황혼육아\'가 내 삶을 이렇게 바꿔놨다.  ▲ \xa0손녀 콩이가 쓴 편지다. 또록또록 정이 가득찬 편지, 고맙고 감사하다. ⓒ 문운주          할아버지 시계         길고 커다란 마루 위 시계는 우리 할아버지 시계90년 전에 할아버지 태어나던 날 아침에 받은 시계란다.언제나 정답게 흔들어주던 시계할아버지의 옛날 시계이젠 더 가질 않네 가지를 않네~~\xa0\xa0 지난 생일날, 아이들과 함께 동요를 불렀다.\xa0맑고 청아한 소리가 가슴 속 깊이 파고든다. 전율을 느꼈다. 10여 년의 세월이 결코 헛되지 않았다. 나의 유일한 전속모델이자, 주연배우, 말동무였던 아이들이 이제 훌쩍 커버렸다. \'애들 크면 당신 곁에는 누가 있을까?\', 아내의 걱정이 아니라도 나부터 이게 걱정이긴 하다.저작권자(c) 오마이뉴스(시민기자), 무단 전재 및 재배포 금지'

# %% [markdown]
# ### Test data

# %%
article = pd.DataFrame(columns=["date", "Title", "sex", "Body"])
today = datetime.datetime.now()

# 1년 치 데이터 
for i in range(1): 
    
    date = today - datetime.timedelta(days=i)
    date = date.strftime('%Y%m%d')
    
    print("date : {} started".format(date))
    male_array, female_array = clawler(date)
    article = article.append(pd.DataFrame(np.concatenate([male_array, female_array]), columns=["date", "Title", "sex", "Body"]))
    print("date : {} done \n".format(date))

import pickle 

with open("article.bin", "wb") as f :
    
    pickle.dump(article, f)
# Out:
# date : 20180729 started
